# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import gmaps
import requests
import json

# %%
#Original Draft Data

master_data = pd.read_csv("../Draft-Research/starting file/Draft_SD_CSV.csv")

#Creating WAR Group column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Only showing draft classes that have had players debut before 2014

working_data = master_data.loc[master_data["Year"] < 2005]

#Draft classes that are still going on

ongoing_data = master_data.loc[master_data["Year"] >= 2005]

#Only includes signed draftees

signing_data = working_data.loc[working_data["Signed"] == "Y"]

#Only includes MLB players

MLB_player_data = working_data[pd.notnull(working_data["playerID"])]

#Only MLB players that signed

signed_MLB_players = MLB_player_data.loc[MLB_player_data["Signed"] == "Y"]

#Grouped by drafting franchise

grouped_by_franchise = signing_data.groupby("Franchise")

#Grouped by year and team

grouped_by_year_team = signing_data.groupby(["Year", "Tm"])

# %%
#Find the number of MLB players in each draft class

MLB_count = working_data.groupby("Year")["playerID"].count()

MLB_count
# Out:
# Year
# 1965    138
# 1966    104
# 1967     85
# 1968    103
# 1969    125
# 1970    101
# 1971    102
# 1972    123
# 1973    101
# 1974    117
# 1975    109
# 1976    123
# 1977    129
# 1978    144
# 1979    141
# 1980    128
# 1981    135
# 1982    156
# 1983    126
# 1984    121
# 1985    150
# 1986    175
# 1987    220
# 1988    195
# 1989    185
# 1990    235
# 1991    209
# 1992    208
# 1993    206
# 1994    214
# 1995    203
# 1996    208
# 1997    208
# 1998    196
# 1999    190
# 2000    203
# 2001    208
# 2002    209
# 2003    223
# 2004    203
# Name: playerID, dtype: int64

# %%
#Draft class summary statistics for MLB players in each draft class

round(MLB_count.describe(),2)
# Out:
# count     40.00
# mean     161.48
# std       45.07
# min       85.00
# 25%      123.00
# 50%      153.00
# 75%      206.50
# max      235.00
# Name: playerID, dtype: float64

# %%
#Player by draft class year bargraph

MLB_count.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", figsize = (16, 10))
plt.title("MLB Players by Draft Year", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("MLB Players Drafted", size = 16)
plt.yticks(np.arange(0, 251, step = 25))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Players by Draft Year.png")
plt.show()

# %%
#Total WAR by draft class year

draft_class_war = working_data.groupby("Year")["Total_WAR"].sum()

draft_class_war
# Out:
# Year
# 1965    511.6
# 1966    379.9
# 1967    415.7
# 1968    397.1
# 1969    445.5
# 1970    332.1
# 1971    339.1
# 1972    538.9
# 1973    442.8
# 1974    411.7
# 1975    317.0
# 1976    487.1
# 1977    404.4
# 1978    596.5
# 1979    480.3
# 1980    369.0
# 1981    665.1
# 1982    695.6
# 1983    467.6
# 1984    385.9
# 1985    540.7
# 1986    539.0
# 1987    613.2
# 1988    594.1
# 1989    596.0
# 1990    504.6
# 1991    535.2
# 1992    522.4
# 1993    466.4
# 1994    541.9
# 1995    590.4
# 1996    564.5
# 1997    529.5
# 1998    657.7
# 1999    614.4
# 2000    656.8
# 2001    654.6
# 2002    737.1
# 2003    559.9
# 2004    597.3
# Name: Total_WAR, dtype: float64

# %%
#Draft class summary statistics for total WAR in each draft class

round(draft_class_war.describe(),2)
# Out:
# count     40.00
# mean     517.46
# std      107.01
# min      317.00
# 25%      436.02
# 50%      532.35
# 75%      596.12
# max      737.10
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_war.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", figsize = (16, 10))
plt.title("Total Draft Class WAR", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(0, 800, step = 50))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Total WAR by Draft Year.png")
plt.show()

# %%
#Create a table by year and WAR groups

draft_year_war_table = pd.crosstab(working_data["Year"], working_data["WAR Group"])
draft_year_war_table = draft_year_war_table[["No Major League Experience", "Less than 5 WAR", "5-10 WAR", "10-15 WAR", 
"15-20 WAR", "20-25 WAR", "More than 25 WAR"]]

draft_year_war_table.to_csv("output data/draft_year_war_table_player_count.csv")

draft_year_war_table
# Out:
# WAR Group  No Major League Experience  Less than 5 WAR  5-10 WAR  10-15 WAR  \
# Year
# 1965                              686              108        11          7
# 1966                              727               76        15          6
# 1967                              890               60         6          8
# 1968                              809               74        13          7
# 1969                              917               98        10          5
# 1970                              826               80         7          6
# 1971                              699               83        10          2
# 1972                              668               90         9          8
# 1973                              646               71        13          4
# 1974                              570               87        13         10
# 1975                              570               88         9          5
# ...

# %%
#Used to find summary statistics of the draft

mlb_player_count = working_data["playerID"].count()

total_draft_picks = working_data["OvPck"].count()

mlb_bust_pct = 100 - round(100 * (mlb_player_count / total_draft_picks),2)

under_five_war = working_data["WAR Group"].loc[(working_data["WAR Group"] == "No Major League Experience") |
                                               (working_data["WAR Group"] == "Less than 5 WAR")].count()

mlb_non_factors = round(100 * (under_five_war / total_draft_picks),2)

print(f"Total MLB players picked through 2004 is {mlb_player_count}.")

print(f"There has been a total of {total_draft_picks} draft picks made through 2004.")

print(f"{mlb_bust_pct}% of draft picks never made it to the Majors.")

print(f"{mlb_non_factors}% of draft picks never produce more than 5 WAR in the Majors.")

under_five_war
# Out:
# Total MLB players picked through 2004 is 6459.
# There has been a total of 45694 draft picks made through 2004.
# 85.86% of draft picks never made it to the Majors.
# 97.0% of draft picks never produce more than 5 WAR in the Majors.
# 44325

# %%
#Creating the same table but with percentages not count

draft_year_war_table_pct = pd.crosstab(working_data["Year"], working_data["WAR Group"], normalize = "index")
draft_year_war_table_pct = draft_year_war_table_pct[["No Major League Experience", "Less than 5 WAR", "5-10 WAR", "10-15 WAR", 
"15-20 WAR", "20-25 WAR", "More than 25 WAR"]]

draft_year_war_table_pct.to_csv("output data/draft_year_war_table_player_pct.csv")

100 * round(draft_year_war_table_pct,3)
# Out:
# WAR Group  No Major League Experience  Less than 5 WAR  5-10 WAR  10-15 WAR  \
# Year
# 1965                             83.3             13.1       1.3        0.8
# 1966                             87.5              9.1       1.8        0.7
# 1967                             91.3              6.2       0.6        0.8
# 1968                             88.7              8.1       1.4        0.8
# 1969                             88.0              9.4       1.0        0.5
# 1970                             89.1              8.6       0.8        0.6
# 1971                             87.3             10.4       1.2        0.2
# 1972                             84.5             11.4       1.1        1.0
# 1973                             86.5              9.5       1.7        0.5
# 1974                             83.0             12.7       1.9        1.5
# 1975                             83.9             13.0       1.3        0.7
# ...

# %%
#Summary statistics by WAR group

round(draft_year_war_table.describe(),2)
# Out:
# WAR Group  No Major League Experience  Less than 5 WAR  5-10 WAR  10-15 WAR  \
# count                           40.00            40.00     40.00      40.00
# mean                           980.88           127.25     14.50       8.38
# std                            325.87            39.94      4.37       3.37
# min                            570.00            60.00      6.00       2.00
# 25%                            695.75            93.00     11.00       6.00
# 50%                            858.00           113.00     14.00       8.00
# 75%                           1274.00           165.50     17.25      10.00
# max                           1530.00           198.00     27.00      21.00
#
# WAR Group  15-20 WAR  20-25 WAR  More than 25 WAR
# count          40.00      40.00             40.00
# mean            5.08       3.12              3.15
# std             1.99       1.90              1.69
# min             0.00       0.00              0.00
# ...

# %%
#Creating a table by year and school type for MLB players

draft_year_school_table = pd.crosstab(MLB_player_data["Year"], MLB_player_data["Type"])

draft_year_school_table
# Out:
# Type  4Yr   HS  JC
# Year
# 1965   53   77   7
# 1966   37   58   9
# 1967    5   77   3
# 1968   29   67   5
# 1969   34   82   9
# 1970   27   70   4
# 1971   20   79   3
# 1972   36   79   8
# 1973   35   58   8
# 1974   39   69   9
# 1975   46   57   6
# 1976   65   57   1
# 1977   67   58   3
# 1978   74   65   4
# 1979   76   60   4
# 1980   70   53   4
# 1981   75   56   2
# 1982   82   71   3
# 1983   75   44   7
# 1984   70   48   3
# 1985  109   35   4
# 1986  105   63   6
# 1987  110   78  31
# 1988  106   61  26
# 1989   98   56  30
# 1990  109   92  33
# 1991  106   73  30
# 1992  110   69  29
# 1993   93   83  30
# 1994   76  103  34
# 1995   89   93  20
# 1996   82   95  30
# 1997   92   84  31
# 1998   93   76  24
# 1999   90   71  29
# 2000   89   84  28
# 2001   88   91  27
# 2002   87   84  38
# 2003   98   87  38
# 2004  109   78  16

# %%
#Creating the same table but with percentages for year instead of count

draft_year_school_table_pct = pd.crosstab(MLB_player_data["Year"], MLB_player_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1965  38.7  56.2   5.1
# 1966  35.6  55.8   8.7
# 1967   5.9  90.6   3.5
# 1968  28.7  66.3   5.0
# 1969  27.2  65.6   7.2
# 1970  26.7  69.3   4.0
# 1971  19.6  77.5   2.9
# 1972  29.3  64.2   6.5
# 1973  34.7  57.4   7.9
# 1974  33.3  59.0   7.7
# 1975  42.2  52.3   5.5
# 1976  52.8  46.3   0.8
# 1977  52.3  45.3   2.3
# 1978  51.7  45.5   2.8
# 1979  54.3  42.9   2.9
# 1980  55.1  41.7   3.1
# 1981  56.4  42.1   1.5
# 1982  52.6  45.5   1.9
# 1983  59.5  34.9   5.6
# 1984  57.9  39.7   2.5
# 1985  73.6  23.6   2.7
# 1986  60.3  36.2   3.4
# 1987  50.2  35.6  14.2
# 1988  54.9  31.6  13.5
# 1989  53.3  30.4  16.3
# 1990  46.6  39.3  14.1
# 1991  50.7  34.9  14.4
# 1992  52.9  33.2  13.9
# 1993  45.1  40.3  14.6
# 1994  35.7  48.4  16.0
# 1995  44.1  46.0   9.9
# 1996  39.6  45.9  14.5
# 1997  44.4  40.6  15.0
# 1998  48.2  39.4  12.4
# 1999  47.4  37.4  15.3
# 2000  44.3  41.8  13.9
# 2001  42.7  44.2  13.1
# 2002  41.6  40.2  18.2
# ...

# %%
# Summary statistics of Major Leaguers in the draft for each school type

round(draft_year_school_table.describe(),2)
# Out:
# Type      4Yr      HS     JC
# count   40.00   40.00  40.00
# mean    73.85   71.03  15.90
# std     29.15   15.07  12.75
# min      5.00   35.00   1.00
# 25%     51.25   58.00   4.00
# 50%     79.00   71.00   9.00
# 75%     94.25   82.25  29.25
# max    110.00  103.00  38.00

# %%
colors = ["navy", "royalblue", "lightblue"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "black", stacked = True, figsize = (16, 10.5))
plt.title("MLB Players by Draft Year and School Type", size = 28)
plt.xlabel("Year Drafted", size = 16)
plt.ylabel("MLB Player %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Players School Type by Draft Year.png")
plt.show()

# %%
#Used to find which franchises have drafted the best historically

franchise_WAR_overall = grouped_by_franchise["Total_WAR"].sum()

franchise_drafts = grouped_by_franchise["Year"].nunique()

avg_franchise_WAR = franchise_WAR_overall / franchise_drafts

round(avg_franchise_WAR.sort_values(ascending = False),2)
# Out:
# Franchise
# Rays                   20.26
# Red Sox                19.02
# Rockies                18.18
# Athletics              18.02
# Cardinals              17.77
# Blue Jays              17.00
# Diamondbacks           16.22
# Angels                 15.88
# Royals                 15.87
# Mariners               15.30
# Nationals              15.20
# Twins                  15.05
# Reds                   15.02
# Rangers                14.55
# Phillies               14.52
# Pirates                14.45
# Mets                   13.74
# Brewers                13.56
# Braves                 13.41
# Yankees                13.34
# Dodgers                13.23
# Astros                 13.05
# Cubs                   12.68
# Tigers                 12.22
# White Sox              12.18
# Indians                11.86
# Orioles                11.68
# Giants                 11.61
# Padres                 11.09
# Marlins                10.77
# Not a MLB Franchise     2.88
# dtype: float64

# %%
#Ignore MiLB franchises that participated in draft

excluding_milb = avg_franchise_WAR[avg_franchise_WAR >= 3].sort_values(ascending = False)

#Which franchises have drafted the best bar graph

excluding_milb.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", figsize = (16, 10))
plt.title("Average Draft Class WAR", size = 28)
plt.xlabel("Franchise", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(0, 22, step = 1))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Average Draft Class WAR by Franchise.png")
plt.show()

# %%
#Finding the total MLB players drafted and signed for each team every year

team_mlb_players = grouped_by_year_team["playerID"].count()

print(team_mlb_players.sort_values(ascending = False))

team_mlb_players.to_csv("output data/yearly_team_mlb_players_results.csv")
# Out:
# Year  Tm
# 2004  Rockies          12
# 1992  Pirates          12
# 1990  Yankees          11
# 1991  Cardinals        11
# 1987  Rangers          11
#                        ..
# 1975  Brewers           0
# 1970  Bend (minors)     0
# 1968  Nationals         0
# 1972  Reds              0
# 1990  ERI               0
# Name: playerID, Length: 1053, dtype: int64

# %%
#Summary statistics for MLB players by year and team

round(team_mlb_players.describe(),2)
# Out:
# count    1053.00
# mean        4.35
# std         2.12
# min         0.00
# 25%         3.00
# 50%         4.00
# 75%         6.00
# max        12.00
# Name: playerID, dtype: float64

# %%
#Limiting graph to draft classes with 9 or more MLB players

best_team_mlb_players = team_mlb_players[team_mlb_players >= 9].sort_values(ascending = False)

#Most MLB players in draft class by year and team bar graph

best_team_mlb_players.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", figsize = (16, 10))
plt.title("Total MLB Players by Year and Team", size = 28)
plt.xlabel("Year and Team", size = 16)
plt.ylabel("MLB Players Signed", size = 16)
plt.yticks(np.arange(0, 13, step = 1))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Players by Team and Year Drafted.png")
plt.show()

# %%
#Finding the total WAR drafted and signed for each team every year

teamWAR = grouped_by_year_team["Total_WAR"].sum()

print(teamWAR.sort_values(ascending = False))

teamWAR.to_csv("output data/yearly_team_draft_results.csv")
# Out:
# Year  Tm
# 1976  Red Sox      79.1
# 1999  Cardinals    76.0
# 1989  Twins        75.4
# 1981  Mariners     71.3
# 1989  Red Sox      71.1
#                    ...
# 1970  Angels       -3.3
# 1974  Cubs         -3.5
# 1973  Braves       -3.5
# 1987  Phillies     -5.4
# 1999  Pirates      -5.7
# Name: Total_WAR, Length: 1053, dtype: float64

# %%
#Summary statistics for total WAR by year and team

round(teamWAR.describe(),2)
# Out:
# count    1053.00
# mean       14.26
# std        14.55
# min        -5.70
# 25%         2.30
# 50%        10.90
# 75%        22.70
# max        79.10
# Name: Total_WAR, dtype: float64

# %%
#Limiting graph to draft classes with 50 or more WAR in their draft class

top_teamWAR = teamWAR[teamWAR >= 50].sort_values(ascending = False)

#Best draft classes by year and team bar graph

top_teamWAR.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", figsize = (16, 16))
plt.title("WAR by Year and Team", size = 28)
plt.xlabel("Year and Team", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(0, 81, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("WAR by Team and Year Drafted.png")
plt.show()

# %%
#Creating a table for position and school type by WAR group

pos_war_table = pd.crosstab([working_data["Type"], working_data["Pos"]], working_data["WAR Group"])
pos_war_table = pos_war_table[["No Major League Experience", "Less than 5 WAR", "5-10 WAR", "10-15 WAR", 
"15-20 WAR", "20-25 WAR", "More than 25 WAR"]]

pos_war_table
# Out:
# WAR Group  No Major League Experience  Less than 5 WAR  5-10 WAR  10-15 WAR  \
# Type Pos
# 4Yr  1B                           916              116        11          6
#      2B                           818               97         7          6
#      3B                           799              117        19         11
#      C                           1568              210        14         11
#      INF                          115               18         0          1
#      LHP                         1931              382        52         25
#      OF                          2849              374        35         26
#      P                             19                1         0          0
#      RHP                         4910              868        83         37
#      SS                          1311              211        29         15
# HS   1B                           882               86        14          8
# ...

# %%
#Creating the same table but for percentages instead of count

pos_war_table_pct = pd.crosstab([working_data["Type"], working_data["Pos"]], working_data["WAR Group"], normalize = "index")
pos_war_table_pct = pos_war_table_pct[["No Major League Experience", "Less than 5 WAR", "5-10 WAR", "10-15 WAR", 
"15-20 WAR", "20-25 WAR", "More than 25 WAR"]]
100 * round(pos_war_table_pct,3)
# Out:
# WAR Group  No Major League Experience  Less than 5 WAR  5-10 WAR  10-15 WAR  \
# Type Pos
# 4Yr  1B                          85.6             10.8       1.0        0.6
#      2B                          87.7             10.4       0.8        0.6
#      3B                          83.2             12.2       2.0        1.1
#      C                           86.7             11.6       0.8        0.6
#      INF                         84.6             13.2       0.0        0.7
#      LHP                         80.0             15.8       2.2        1.0
#      OF                          85.8             11.3       1.1        0.8
#      P                           95.0              5.0       0.0        0.0
#      RHP                         82.6             14.6       1.4        0.6
#      SS                          82.9             13.3       1.8        0.9
# HS   1B                          88.0              8.6       1.4        0.8
# ...

# %%
#Creating a bar graph for MLB% by position and type

pos_no_mlb_pct = pos_war_table_pct[["No Major League Experience"]].sort_values(by = ["No Major League Experience"], ascending = True)

100 - (100 * round(pos_no_mlb_pct,3))

(100 - (100 * round(pos_no_mlb_pct,3))).plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", legend = False, figsize = (16, 16))
plt.title("MLB Success Rate by School Type and Position", size = 28)
plt.xlabel("School Type and Position", size = 16)
plt.ylabel("Major League Player %", size = 16)
plt.yticks(np.arange(0, 21, step = 1))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Success Rate by School and Position.png")
plt.show()

# %%
#Creating a bar graph for MLB% by position and type exlcluding smaller samples

pos_war_table_pct_shortened = pos_war_table_pct.loc[pos_war_table["No Major League Experience"] >= 150]

pos_war_table_pct_shortened = pos_war_table_pct_shortened[["No Major League Experience"]].sort_values(by = ["No Major League Experience"], ascending = True)

100 - (100 * round(pos_war_table_pct_shortened,3))

(100 - (100 * round(pos_war_table_pct_shortened,3))).plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", legend = False, figsize = (16, 16))
plt.title("MLB Success Rate by School Type and Position", size = 28)
plt.xlabel("School Type and Position", size = 16)
plt.ylabel("Major League Player %", size = 16)
plt.yticks(np.arange(0, 21, step = 1))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Success Rate by School and Position (shortened).png")
plt.show()

# %%
#Creating table to show which universities have produced the most MLB players

college_mlb_players = MLB_player_data.loc[MLB_player_data["Type"] == "4Yr"]

#Removing any players that were drafted multiple times from their school

deduped_college_mlb_players = college_mlb_players.drop_duplicates(subset = ("playerID", "School"), keep = "last")

college_list = deduped_college_mlb_players.groupby(["School"])["playerID"].count().sort_values(ascending = False)

print(college_list)
# Out:
# School
# Arizona State University                 71
# Stanford University                      60
# University of Texas at Austin            50
# University of Southern California        47
# California State University Fullerton    42
#                                          ..
# University of Arkansas at Little Rock     1
# University of British Columbia            1
# University of Central Arkansas            1
# John J Pershing College                   1
# Abilene Christian University              1
# Name: playerID, Length: 457, dtype: int64

# %%
#Creating a bar graph for which universities produce the most major leaguers

shortened_college_list = college_list[college_list >= 20]

shortened_college_list.plot(kind = "bar", color = "royalblue", width = .8, fontsize = 12, edgecolor = "black", legend = False, figsize = (16, 16))
plt.title("MLB Players Drafted by College", size = 28)
plt.xlabel("School", size = 16)
plt.ylabel("Number of MLB Players Drafted", size = 16)
plt.yticks(np.arange(0, 76, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("MLB Drafted by College.png")
plt.show()

# %%
#Using Google Geocoding API to find the Lattitude and Longitude of where the MLB player was drafted from

map_data = MLB_player_data

#Making a new column that contains both City and State for API call
map_data["location"] = map_data["City"] + ", " + map_data["State"]

lat = []
lng = []

for location in map_data["location"]:
    url = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = {"address" : location,
         "key" : "Your API Here!"}
    response = requests.get(url, params=params).json()
    lat.append(response["results"][0]["geometry"]["location"]["lat"])
    lng.append(response["results"][0]["geometry"]["location"]["lng"])

#Making New columns
map_data["lat"] = lat
map_data["lng"] = lng

#Making the vairables for the Heat Map
map_coor = map_data[["lat", "lng"]]

map_data.to_csv("output data/MLB Players with Map Coordinates.csv")

#count = map_data["playerID"].count().astype(float)
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-69ef9bee0eba> in <module>
#      14          "key" : "Your API Here!"}
#      15     response = requests.get(url, params=params).json()
# ---> 16     lat.append(response["results"][0]["geometry"]["location"]["lat"])
#      17     lng.append(response["results"][0]["geometry"]["location"]["lng"])
#      18
#
# IndexError: list index out of range

# %%
#Google Heat Map
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(map_coor, dissipating=False, point_radius=1)

fig.add_layer(heat_layer)

fig
